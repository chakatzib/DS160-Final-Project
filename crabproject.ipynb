# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt

# %%
df=pd.read_csv("CrabAgePrediction.csv")

# %%
df.head(100)
# Out:
#    Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0    F  1.4375    1.1750  0.4125  24.635715       12.332033        5.584852
# 1    M  0.8875    0.6500  0.2125   5.400580        2.296310        1.374951
# 2    I  1.0375    0.7750  0.2500   7.952035        3.231843        1.601747
# 3    F  1.1750    0.8875  0.2500  13.480187        4.748541        2.282135
# 4    I  0.8875    0.6625  0.2125   6.903103        3.458639        1.488349
# ..  ..     ...       ...     ...        ...             ...             ...
# 95   F  1.3250    1.0125  0.3750  25.202706       11.495722        6.449511
# 96   I  0.7375    0.5375  0.1875   3.288542        1.048931        0.836310
# 97   I  1.3750    1.0625  0.3875  24.734939       11.679994        5.301356
# 98   M  1.7375    1.3250  0.5250  42.807745       18.824068       11.609120
# 99   I  1.3500    1.0625  0.3500  21.035329        9.071840        3.954755
#
#     Shell Weight  Age
# 0       6.747181    9
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3893 entries, 0 to 3892
# Data columns (total 9 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Sex             3893 non-null   object
#  1   Length          3893 non-null   float64
#  2   Diameter        3893 non-null   float64
#  3   Height          3893 non-null   float64
#  4   Weight          3893 non-null   float64
#  5   Shucked Weight  3893 non-null   float64
#  6   Viscera Weight  3893 non-null   float64
#  7   Shell Weight    3893 non-null   float64
#  8   Age             3893 non-null   int64
# dtypes: float64(7), int64(1), object(1)
# memory usage: 273.9+ KB

# %%
df.describe()
# Out:
#             Length     Diameter       Height       Weight  Shucked Weight  \
# count  3893.000000  3893.000000  3893.000000  3893.000000     3893.000000
# mean      1.311306     1.020893     0.349374    23.567275       10.207342
# std       0.300431     0.248233     0.104976    13.891201        6.275275
# min       0.187500     0.137500     0.000000     0.056699        0.028349
# 25%       1.125000     0.875000     0.287500    12.672227        5.343881
# 50%       1.362500     1.062500     0.362500    22.792998        9.539607
# 75%       1.537500     1.200000     0.412500    32.786197       14.273973
# max       2.037500     1.625000     2.825000    80.101512       42.184056
#
#        Viscera Weight  Shell Weight          Age
# count     3893.000000   3893.000000  3893.000000
# mean         5.136546      6.795844     9.954791
# std          3.104133      3.943392     3.220967
# min          0.014175      0.042524     1.000000
# 25%          2.664853      3.713785     8.000000
# ...

# %%
df_line=pd.read_csv("CrabAgePrediction.csv")

# %%
fig=plt.figure(figsize=(16,16))
fig.suptitle("Different Measures of Crab Weight and their Correlation to sex and measures of size",fontsize=10)

ax1=fig.add_subplot(331) # 3 rows 3 columns position 1
ax1.set_title("Weight and Length")
ax1.scatter(df_line['Weight'],
        df_line['Length'],
        color='green')
ax2=fig.add_subplot(332) # 3 rows 3 columns position 2
ax2.set_title("Weight and Diameter")
ax2.scatter(df_line['Weight'],
        df_line['Diameter'],
        color='purple')
ax3=fig.add_subplot(333) # 3 row 3 column position 3
ax3.set_title("Weight and Height")
ax3.scatter(df_line['Weight'],
        df_line['Height'],
        color='magenta')
ax4=fig.add_subplot(334) # 3 rows 3 columns position 4
ax4.set_title("Age and Length")
ax4.scatter(df_line['Age'],
        df_line['Length'],
        color='green')
ax5=fig.add_subplot(335) # 3 rows 3 columns position 5
ax5.set_title("Age and Diameter")
ax5.scatter(df_line['Age'],
        df_line['Diameter'],
        color='purple')
ax6=fig.add_subplot(336) # 3 row 3 column position 6
ax6.set_title("Age and Height")
ax6.scatter(df_line['Age'],
        df_line['Height'],
        color='magenta')

ax7=fig.add_subplot(337) # 3 rows 3 columns position 7
ax7.set_title("Age and Shucked Weight")
ax7.scatter(df_line['Age'],
        df_line['Shucked Weight'],
        color='green')
ax8=fig.add_subplot(338) # 3 rows 3 columns position 8
ax8.set_title("Age and Viscera Weight")
ax8.scatter(df_line['Age'],
        df_line['Viscera Weight'],
        color='purple')
ax9=fig.add_subplot(339) # 3 row 3 column position 9
ax9.set_title("Age and Shell Weight")
ax9.scatter(df_line['Age'],
        df_line['Shell Weight'],
        color='magenta')
plt.show()

# %%
plt.scatter(df_line['Age'],
           df_line['Weight'])
plt.title("Crab Age and Weight")
plt.xlabel("Age")
plt.ylabel("Weight")
plt.show()

# %%
df.isnull().sum()
# Out:
# Sex               0
# Length            0
# Diameter          0
# Height            0
# Weight            0
# Shucked Weight    0
# Viscera Weight    0
# Shell Weight      0
# Age               0
# dtype: int64

# %% [markdown]
# # splitting into training and test sets

# %%
df.columns
# Out:
# Index(['Sex', 'Length', 'Diameter', 'Height', 'Weight', 'Shucked Weight',
#        'Viscera Weight', 'Shell Weight', 'Age'],
#       dtype='object')

# %%
x=df[['Length','Diameter','Height','Shucked Weight','Viscera Weight','Shell Weight','Age']]
y=df[['Weight']]

# %%
from sklearn.model_selection import train_test_split

# %%
x_train,x_test,y_train,y_test = train_test_split(x,y,test_size=.20,random_state=0)

# %% [markdown]
# # Linear regression

# %%
from sklearn.linear_model import LinearRegression

regressor=LinearRegression()
#.fit to train your model
regressor.fit(x_train.values,y_train)
# Out:
# LinearRegression()

# %%
print(f"Coefficient: {regressor.coef_}")
# Out:
# Coefficient: [[-0.23631685  0.24949422  0.01825216  0.9635066   1.13067751  1.14578486
#    0.11286443]]

# %%
y_pred=regressor.predict(x_test.values)

# %%
from sklearn.metrics import mean_squared_error, r2_score
import math

# %%
print(F"RMSE: {math.sqrt(mean_squared_error(y_test,y_pred)):.2f}")
# Out:
# RMSE: 1.44

# %%
print(f"R-square: {r2_score(y_test,y_pred):.2f}")
# Out:
# R-square: 0.99

# %% [markdown]
# # Prediction test

# %%
df.head()
# Out:
#   Sex  Length  Diameter  Height     Weight  Shucked Weight  Viscera Weight  \
# 0   F  1.4375    1.1750  0.4125  24.635715       12.332033        5.584852
# 1   M  0.8875    0.6500  0.2125   5.400580        2.296310        1.374951
# 2   I  1.0375    0.7750  0.2500   7.952035        3.231843        1.601747
# 3   F  1.1750    0.8875  0.2500  13.480187        4.748541        2.282135
# 4   I  0.8875    0.6625  0.2125   6.903103        3.458639        1.488349
#
#    Shell Weight  Age
# 0      6.747181    9
# 1      1.559222    6
# 2      2.764076    6
# 3      5.244657   10
# 4      1.700970    6

# %%
regressor.predict([[1.4375,1.1750,0.4125,12.332033,5.584852,6.747181,9]])
# Out:
# array([[25.96420046]])

# %%
regressor.predict([[0.8875,0.6500,0.2125,2.296310,1.374951,1.559222,6]])
# Out:
# array([[5.24713593]])

# %%
regressor.predict([[1.0375,0.7750,0.2500,3.231843,1.601747,2.764076,6]])
# Out:
# array([[7.78188847]])

# %%
regressor.predict([[1.1750,0.8875,0.2500,4.748541,2.282135,5.244657,10]])
# Out:
# array([[13.30178082]])

# %% [markdown]
# The model managed to predict the weight with pretty good accuracy. The R Square value is 0.99, and the RMSE is 1.44, and this shows that the model was very nicely trained and able to predict thingss sufficiently.
